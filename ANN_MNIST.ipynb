# %%
 import tensorflow as tf
 import matplotlib.pyplot as plt

# %%
mnist=tf.keras.datasets.mnist

# %%
(train_x,train_y),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
train_x=train_x/255.0
x_test=x_test/255.0
print(train_x.shape,train_y.shape,x_test.shape,y_test.shape,sep=" ")
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)

# %%
model=tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),tf.keras.layers.Dense(128,activation='relu'),tf.keras.layers.Dropout(0.2),tf.keras.layers.Dense(10,activation="softmax")])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
r=model.fit(train_x, train_y, validation_data=(x_test,y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4845 - accuracy: 0.8628 - val_loss: 0.1412 - val_accuracy: 0.9597
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1462 - accuracy: 0.9565 - val_loss: 0.1034 - val_accuracy: 0.9686
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1046 - accuracy: 0.9691 - val_loss: 0.0826 - val_accuracy: 0.9738
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0842 - accuracy: 0.9735 - val_loss: 0.0770 - val_accuracy: 0.9764
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0702 - accuracy: 0.9783 - val_loss: 0.0715 - val_accuracy: 0.9777
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0619 - accuracy: 0.9798 - val_loss: 0.0677 - val_accuracy: 0.9800
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0524 - accuracy: 0.9835 - val_loss: 0.0709 - val_accuracy: 0.9793
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0508 - accuracy: 0.9835 - val_loss: 0.0678 - val_accuracy: 0.9801
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0454 - accuracy: 0.9844 - val_loss: 0.0648 - val_accuracy: 0.9793
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0422 - accuracy: 0.9859 - val_loss: 0.0645 - val_accuracy: 0.9808

# %%
plt.plot(r.history['accuracy']);

# %%
plt.plot(r.history['loss']);

# %%
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend();

# %%
plt.plot(r.history['accuracy'],label='acc')
plt.plot(r.history['val_accuracy'],label='val_acc')
plt.legend();

# %%
print(model.evaluate(x_test,y_test))
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0645 - accuracy: 0.9808
# [0.0644509419798851, 0.9807999730110168]
